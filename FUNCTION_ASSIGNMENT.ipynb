# %% [markdown]
# #Q1. What is the difference between a function and a method in Python?
#
# ----- Functions are nothing but a block of code which performs a specific task and can be called again and again as
# per requirement in the code.
#
# Function:
# A function is defined using the def keyword.
#
# It can exist independently, outside of any class.
#
# You call a function directly using its name.

# %%
def greet(name):
    return f"Hello, {name}!"

print(greet("sourav"))
# Out:
# Hello, sourav!

# %% [markdown]
# Method:
# A method is also defined using def, but it’s inside a class.
#
# It is called on an object (an instance of a class) and usually takes self as its first parameter.
#
# It acts on the object it belongs to.

# %%
class Greeter:
    def greet(self, name):
        return f"Hello, {name}!"

g = Greeter()
print(g.greet("Sourav"))  # greet is a method
# Out:
# Hello, Sourav!

# %% [markdown]
# #Q2. Explain the concept of function arguments and parameters in Python.
#
#
# -------Function arguments are values that you provide to a function when you call it. These arguments can be
# used by the function to perform specific tasks.

# %%
# Positional Arguments -

def add(a, b):
    return a + b

add(2, 3)
# Out:
# 5

# %%
#Default Arguments

def greet(name="Sourav"):
    print(f"Hello, {name}")

greet()
greet("sonu")
# Out:
# Hello, Sourav
# Hello, sonu

# %%
#Variable-length Arguments:
# args (Non-keyword arguments as a tuple)

# kwargs (Keyword arguments as a dictionary)
def show(*args, **kwargs):
    print(args)
    print(kwargs)

show(1, 2, a=3, b=4)
# Out:
# (1, 2)
# {'a': 3, 'b': 4}

# %% [markdown]
# #Q 3. What are the different ways to define and call a function in Python?
#
# -------- Functions can be defined and called in several ways depending on the use case. Here's a breakdown of the different ways to define and call functions:

# %%
#Standard Function :-
def greet(name):
    return f"Hello, {name}!"

# Call:
greet("Sourav")
# Out:
# 'Hello, Sourav!'

# %%
#Function with Default Arguments :-

def greet(name="Guest"):
    return f"Hello, {name}!"

greet()
greet("Sonu")
# Out:
# 'Hello, Sonu!'

# %%
#Variable-length Arguments :-

def show_args(*args):
    print(args)

show_args(1, 2, 3)

def show_kwargs(**kwargs):
    print(kwargs)

show_kwargs(a=1, b=2)
# Out:
# (1, 2, 3)
# {'a': 1, 'b': 2}

# %%
#Lambda Functions :-
add = lambda x, y: x + y
add(2, 3)
# Out:
# 5

# %%
#Nested Functions :-

def outer():
    def inner():
        return "Inner"
    return inner()

outer()  # Calls inner() from within outer()
# Out:
# 'Inner'

# %%
#Calling Functions with Positional :-

def describe(name, age):
    return f"{name} is {age} years old."

describe("Sourav", 26)
describe(age=26, name="Sourav")
# Out:
# 'Sourav is 26 years old.'

# %%
#First-Class Functions ;-

def shout(text):
    return text.upper()

talk = shout  # assign function to variable
talk("hello")  # Outputs: HELLO
# Out:
# 'HELLO'

# %% [markdown]
# #Q4. What is the purpose of the `return` statement in a Python function?
#
# ------ The return statement can send a value or object back to the caller of the function. This returned value can then be used for further processing, assigned to a variable, or passed as an argument to another function. If no expression is provided after the return keyword, or if the return statement is omitted entirely, the function returns None by default.

# %%
def add(x, y):
    return x + y

result = add(5, 3)
print(result)
# Out:
# 8

# %% [markdown]
# #Q 5. What are iterators in Python and how do they differ from iterables ?
#
# -------Iterable :
#
#  An iterable is any Python object capable of returning its members one at a time.
# You can loop over it using a for loop.
#
# i.e: list, tuple, str, dict, set

# %%
my_list = [1, 2, 3]
for item in my_list:
    print(item)
# Out:
# 1
# 2
# 3

# %% [markdown]
# Iterator :
#
# An iterator is the object that does the actual iteration. It keeps track of where it is in a sequence.
#
# __iter__() → returns the iterator itself
#
# __next__() → returns the next item, or raises StopIteration when done

# %%
my_iter = iter([1, 2, 3])
print(next(my_iter))
print(next(my_iter))
print(next(my_iter))
# print(next(my_iter))
# Out:
# 1
# 2
# 3

# %% [markdown]
# #Q 6. Explain the concept of generators in Python and how they are defined.
#
# -------
# A generator is a function that uses the yield keyword to produce a sequence of values lazily, one at a time.
#
# Unlike normal functions that return a single value and exit, a generator function pauses its state when yield is used and resumes where it left off when called again.

# %%
def count_up_to(max):
    count = 1
    while count <= max:
        yield count
        count += 1


gen = count_up_to(3)
print(next(gen))
print(next(gen))
print(next(gen))
# Out:
# 1
# 2
# 3

# %% [markdown]
# #Q 7. What are the advantages of using generators over regular functions?
#
#
# ---------Generators offer several advantages over regular functions, primarily related to memory efficiency and performance, especially when dealing with large datasets or infinite sequences. They generate values on demand, reducing the memory footprint and enabling lazy evaluation, which can improve performance. Additionally, generators can be easily composed to create powerful data processing pipelines.
# Here's a more detailed breakdown of the advantages:
#
# #Memory Efficiency:-
#
# Generators produce values one at a time, unlike regular functions that generate and store the entire sequence in memory. This is particularly beneficial when working with large datasets or infinite sequences where storing the entire result would be impractical or impossible.
#
# #Lazy Evaluation:-
#
# Generators evaluate expressions only when needed, providing a performance boost, especially when dealing with complex calculations or large amounts of data.
#
# #Composability:-
#
# Generators can be chained together to create powerful data processing pipelines, enabling efficient and modular code.
#
# #Readability and Conciseness:-
#
# Generators often lead to more concise and readable code compared to traditional loops, as they can express iterative logic in a more compact way.
#
# #Infinite Sequences:-
# Generators can easily handle infinite sequences by generating values on demand, without needing to store them all in memory.
#
#
# #Resource Pipeline:-
#
# Generators enable creating resource pipelines, where data processing tasks are divided into a sequence of generator functions, each processing a segment of data and forwarding it to the next stage.

# %%
def regular_range(n):
    return [i for i in range(n)]

def generator_range(n):
    for i in range(n):
        yield i

# %% [markdown]
# #Q8. What is a lambda function in Python and when is it typically used?
#
# ------- A lambda function in Python is a small, anonymous function defined using the lambda keyword. It's typically used for single-purpose, short-term tasks, especially when passing a function as an argument to another function.

# %%
add = lambda x, y: x + y
print(add(2, 3))
# Out:
# 5

# %%
#With built-in functions like map(), filter(), sorted()

nums = [1, 2, 3, 4, 5]
squares = list(map(lambda x: x**2, nums))

# %%
#Sorting with custom keys


people = [('Sourav', 26), ('raju', 25), ('sonu', 24)]
sorted_by_age = sorted(people, key=lambda x: x[1])

# %% [markdown]
# #Q9. Explain the purpose and usage of the `map()` function in Python.
#
# --------The map() function is a built-in utility that allows you to apply a specified function to each item of an iterable (like a list, tuple, or set), returning a new iterator with the transformed items. This approach is particularly useful for performing element-wise transformations in a concise and readable manner.

# %%
#Using a Built-in Function :-
numbers = ['1', '2', '3']
result = map(int, numbers)
print(list(result))
# Out:
# [1, 2, 3]

# %%
#Using a Lambda Function :-

numbers = [1, 2, 3, 4]
doubled = map(lambda x: x * 2, numbers)
print(list(doubled))
# Out:
# [2, 4, 6, 8]

# %%
#Using a User-defined Function :-
def square(n):
    return n * n

numbers = [1, 2, 3, 4]
squared = map(square, numbers)
print(list(squared))  # Output: [1, 4, 9, 16]
# Out:
# [1, 4, 9, 16]

# %%
#Using Multiple Iterables :-

a = [1, 2, 3]
b = [4, 5, 6]
summed = map(lambda x, y: x + y, a, b)
print(list(summed))
# Out:
# [5, 7, 9]

# %% [markdown]
# #Q10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
#
# -------The map(), filter(), and reduce() functions are built-in higher-order functions in Python that operate on iterables (like lists, tuples, etc.). They each serve distinct purposes:
#
# # map(): Transforming Elements :
# Purpose: Applies a specified function to each item in an iterable, returning a new iterator with the transformed items.​
#
# Syntax: map(function, iterable)​
#
# Eg:

# %%
  numbers = [1, 2, 3, 4]
  squared = list(map(lambda x: x ** 2, numbers))
  print(squared)
# Out:
# [1, 4, 9, 16]

# %% [markdown]
# #filter(): Selecting Elements
# Purpose: Filters elements from an iterable based on a function that returns True or False. Only elements for which the function returns True are included in the result.​
#
# Syntax: filter(function, iterable)
# ​
#
# Eg:

# %%
  numbers = [1, 2, 3, 4]
  even_numbers = list(filter(lambda x: x % 2 == 0, numbers))
  print(even_numbers)
# Out:
# [2, 4]

# %% [markdown]
# #reduce(): Aggregating Elements :-
#
# Purpose: Applies a function cumulatively to the items of an iterable, reducing the iterable to a single accumulated value.​
#
# Syntax: reduce(function, iterable[, initializer])​
#
#
# Note: In reduce() is available in the functools module and must be imported explicitly.​
#
# Eg:

# %%
  from functools import reduce

  numbers = [1, 2, 3, 4]
  product = reduce(lambda x, y: x * y, numbers)
  print(product)  # Output: 24
# Out:
# 24

# %% [markdown]
# #Q11. Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given list:[47,11,42,13];
#
# ----The internal mechanism of the reduce() function when summing the list [47, 11, 42, 13], let's break down the step-by-step process:

# %%
[47, 11, 42, 13]

# %%
from functools import reduce
import operator

result = reduce(operator.add, [47, 11, 42, 13])
print(result)
# Out:
# 113

# %% [markdown]
# #Practical Questions:

# %% [markdown]
# #Q1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.

# %%
def sum_even_numbers(numbers):
    return sum(num for num in numbers if num % 2 == 0)

numbers = [1, 2, 3, 4, 5, 6]
result = sum_even_numbers(numbers)
print("Sum of even numbers:", result)
# Out:
# Sum of even numbers: 12

# %% [markdown]
# #Q2. Create a Python function that accepts a string and returns the reverse of that string.

# %%
text = "Hello, Sourav!"
reversed_text = reverse_string(text)
print(reversed_text)  # Output: !dlroW ,olleH
# Out:
# !varuoS ,olleH

# %% [markdown]
# #Q3. Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.

# %%
def square_numbers(numbers):
    squared_list = []
    for number in numbers:
        squared_list.append(number ** 2)
    return squared_list

numbers = [1, 2, 3, 4, 5]
squared_numbers_list = square_numbers(numbers)
print(squared_numbers_list)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# #Q4. Write a Python function that checks if a given number is prime or not from 1 to 200.

# %%
def is_prime(n):
    if n <= 1:
        return False
    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False
    return True

for num in range(1, 201):
    if is_prime(num):
        print(f"{num} is a prime number.")
# Out:
# 2 is a prime number.
# 3 is a prime number.
# 5 is a prime number.
# 7 is a prime number.
# 11 is a prime number.
# 13 is a prime number.
# 17 is a prime number.
# 19 is a prime number.
# 23 is a prime number.
# 29 is a prime number.
# 31 is a prime number.
# 37 is a prime number.
# 41 is a prime number.
# 43 is a prime number.
# 47 is a prime number.
# 53 is a prime number.
# 59 is a prime number.
# 61 is a prime number.
# 67 is a prime number.
# 71 is a prime number.
# 73 is a prime number.
# 79 is a prime number.
# 83 is a prime number.
# 89 is a prime number.
# 97 is a prime number.
# 101 is a prime number.
# 103 is a prime number.
# 107 is a prime number.
# 109 is a prime number.
# 113 is a prime number.
# 127 is a prime number.
# 131 is a prime number.
# 137 is a prime number.
# 139 is a prime number.
# 149 is a prime number.
# 151 is a prime number.
# 157 is a prime number.
# 163 is a prime number.
# 167 is a prime number.
# 173 is a prime number.
# 179 is a prime number.
# ...

# %% [markdown]
# #Q5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.

# %%
class Fibonacci:
    def __init__(self, max_terms):
        self.max_terms = max_terms
        self.count = 0
        self.a, self.b = 0, 1

    def __iter__(self):
        return self

    def __next__(self):
        if self.count >= self.max_terms:
            raise StopIteration
        if self.count == 0:
            self.count += 1
            return self.a
        elif self.count == 1:
            self.count += 1
            return self.b
        else:
            self.a, self.b = self.b, self.a + self.b
            self.count += 1
            return self.a


fib_sequence = Fibonacci(10)
for num in fib_sequence:
    print(num)
# Out:
# 0
# 1
# 1
# 1
# 2
# 3
# 5
# 8
# 13
# 21

# %% [markdown]
# #Q6. Write a generator function in Python that yields the powers of 2 up to a given exponent.

# %%
def powers_of_2(exponent):
    for i in range(exponent + 1):
        yield 2**i

for power in powers_of_2(5):
    print(power)
# Out:
# 1
# 2
# 4
# 8
# 16
# 32

# %% [markdown]
# #Q7. Implement a generator function that reads a file line by line and yields each line as a string.

# %%
# prompt: 7. Implement a generator function that reads a file line by line and yields each line as a string.

def read_file_line_by_line(filepath):
    """
    Reads a file line by line and yields each line as a string.
    """
    try:
        with open(filepath, 'r') as file:
            for line in file:
                yield line.strip()  # Remove leading/trailing whitespace
    except FileNotFoundError:
        print(f"Error: File not found at '{filepath}'")
        yield None # Or raise an exception if you prefer

# Example usage
# for line in read_file_line_by_line("my_file.txt"):
#     if line is not None:
#       print(line)

# %%
def read_file_line_by_line(filepath):
    """
    Reads a file line by line and yields each line as a string.
    """
    try:
        with open(filepath, 'r') as file:
            for line in file:
                yield line.strip()
    except FileNotFoundError:
        print(f"Error: File not found at '{filepath}'")
        yield None


for line in read_file_line_by_line("my_file.txt"):
     if line is not None:
       print(line)
# Out:
# Error: File not found at 'my_file.txt'

# %% [markdown]
# #Q8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

# %%
people = [('Sourav', 26), ('Rahul', 25), ('Ranjeet', 29)]
sorted_people = sorted(people, key=lambda x: x[1])
sorted_people
# Out:
# [('Rahul', 25), ('Sourav', 26), ('Ranjeet', 29)]

# %% [markdown]
# #Q10. Create a Python program that uses `filter()` to remove all the vowels from a given string.

# %%
def remove_vowels(string):
  vowels = "aeiouAEIOU"
  return "".join(filter(lambda char: char not in vowels, string))

input_string = "Hello, Sourav!"
result = remove_vowels(input_string)
print(result)  # Output: Hll, Wrld!
# Out:
# Hll, Srv!
